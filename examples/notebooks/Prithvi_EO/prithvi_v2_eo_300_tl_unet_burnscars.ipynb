# %% [markdown]
# # Setup
# 1. In colab: Go to "Runtime" -> "Change runtime type" -> Select "T4 GPU"
# 2. Install TerraTorch

# %%
# !pip install terratorch==0.99.9 gdown tensorboard
# Out:
# Requirement already satisfied: terratorch==0.99.9 in /opt/app-root/lib64/python3.11/site-packages (0.99.9)
# Requirement already satisfied: gdown in /opt/app-root/lib64/python3.11/site-packages (5.2.0)
# Requirement already satisfied: tensorboard in /opt/app-root/lib64/python3.11/site-packages (2.17.1)
# Requirement already satisfied: torch==2.6.0 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (2.6.0)
# Requirement already satisfied: torchvision==0.21.0 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.21.0)
# Requirement already satisfied: rioxarray==0.18.2 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.18.2)
# Requirement already satisfied: albumentations==1.4.6 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.4.6)
# Requirement already satisfied: albucore==0.0.16 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.0.16)
# Requirement already satisfied: rasterio==1.4.3 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.4.3)
# Requirement already satisfied: torchmetrics==1.6.2 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.6.2)
# Requirement already satisfied: geopandas==1.0.1 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.0.1)
# Requirement already satisfied: lightly==1.5.19 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.5.19)
# Requirement already satisfied: jsonargparse<=4.35.0 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (4.35.0)
# Requirement already satisfied: h5py==3.13.0 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (3.13.0)
# Requirement already satisfied: mlflow==2.20.3 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (2.20.3)
# Requirement already satisfied: lightning==2.5.0.post0 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (2.5.0.post0)
# Requirement already satisfied: segmentation-models-pytorch in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.4.0)
# Requirement already satisfied: pytest==8.3.5 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (8.3.5)
# Requirement already satisfied: torchgeo==0.6.2 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.6.2)
# Requirement already satisfied: einops==0.8.1 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (0.8.1)
# Requirement already satisfied: timm>=1.0.15 in /opt/app-root/lib64/python3.11/site-packages (from terratorch==0.99.9) (1.0.15)
# Requirement already satisfied: numpy>=1.24 in /opt/app-root/lib64/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.9) (2.1.3)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /opt/app-root/lib64/python3.11/site-packages (from albucore==0.0.16->terratorch==0.99.9) (4.11.0.86)
# Requirement already satisfied: scipy>=1.10.0 in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (1.14.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (0.25.2)
# Requirement already satisfied: PyYAML in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (4.12.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (1.5.2)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/app-root/lib64/python3.11/site-packages (from albumentations==1.4.6->terratorch==0.99.9) (2.10.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/app-root/lib64/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.9) (0.10.0)
# Requirement already satisfied: packaging in /opt/app-root/lib64/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.9) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /opt/app-root/lib64/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.9) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/app-root/lib64/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.9) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/app-root/lib64/python3.11/site-packages (from geopandas==1.0.1->terratorch==0.99.9) (2.0.7)
# Requirement already satisfied: certifi>=14.05.14 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (2025.1.31)
# Requirement already satisfied: hydra-core>=1.0.0 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (1.3.2)
# Requirement already satisfied: lightly_utils~=0.0.0 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (0.0.2)
# Requirement already satisfied: python_dateutil>=2.5.3 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (2.9.0.post0)
# Requirement already satisfied: requests>=2.23.0 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (2.32.3)
# Requirement already satisfied: six>=1.10 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (4.67.1)
# Requirement already satisfied: pytorch_lightning>=1.0.4 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (2.5.0.post0)
# Requirement already satisfied: urllib3>=1.25.3 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (1.26.20)
# Requirement already satisfied: aenum>=3.1.11 in /opt/app-root/lib64/python3.11/site-packages (from lightly==1.5.19->terratorch==0.99.9) (3.1.15)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /opt/app-root/lib64/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (2025.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /opt/app-root/lib64/python3.11/site-packages (from lightning==2.5.0.post0->terratorch==0.99.9) (0.14.1)
# Requirement already satisfied: mlflow-skinny==2.20.3 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (2.20.3)
# Requirement already satisfied: Flask<4 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (3.1.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (1.15.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (3.7)
# Requirement already satisfied: matplotlib<4 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (3.9.4)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (19.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow==2.20.3->terratorch==0.99.9) (2.0.39)
# Requirement already satisfied: iniconfig in /opt/app-root/lib64/python3.11/site-packages (from pytest==8.3.5->terratorch==0.99.9) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/app-root/lib64/python3.11/site-packages (from pytest==8.3.5->terratorch==0.99.9) (1.5.0)
# Requirement already satisfied: affine in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (2.4.0)
# Requirement already satisfied: attrs in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (25.1.0)
# Requirement already satisfied: click>=4.0 in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/app-root/lib64/python3.11/site-packages (from rasterio==1.4.3->terratorch==0.99.9) (3.2.1)
# Requirement already satisfied: xarray>=2024.7.0 in /opt/app-root/lib64/python3.11/site-packages (from rioxarray==0.18.2->terratorch==0.99.9) (2025.1.2)
# Requirement already satisfied: filelock in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (3.17.0)
# Requirement already satisfied: networkx in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/app-root/lib64/python3.11/site-packages (from torch==2.6.0->terratorch==0.99.9) (1.13.1)
# Requirement already satisfied: fiona>=1.8.21 in /opt/app-root/lib64/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.9) (1.10.1)
# Requirement already satisfied: kornia>=0.7.3 in /opt/app-root/lib64/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.9) (0.8.0)
# Requirement already satisfied: pillow>=8.4 in /opt/app-root/lib64/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.9) (11.1.0)
# Requirement already satisfied: rtree>=1 in /opt/app-root/lib64/python3.11/site-packages (from torchgeo==0.6.2->terratorch==0.99.9) (1.4.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (0.46.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (1.31.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (1.31.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (4.25.6)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/app-root/lib64/python3.11/site-packages (from mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (0.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/app-root/lib64/python3.11/site-packages (from sympy==1.13.1->torch==2.6.0->terratorch==0.99.9) (1.3.0)
# Requirement already satisfied: beautifulsoup4 in /opt/app-root/lib64/python3.11/site-packages (from gdown) (4.13.3)
# Requirement already satisfied: absl-py>=0.4 in /opt/app-root/lib64/python3.11/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/app-root/lib64/python3.11/site-packages (from tensorboard) (1.70.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/app-root/lib64/python3.11/site-packages (from tensorboard) (74.1.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/app-root/lib64/python3.11/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/app-root/lib64/python3.11/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: efficientnet-pytorch>=0.6.1 in /opt/app-root/lib64/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.9) (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.24 in /opt/app-root/lib64/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.9) (0.29.3)
# Requirement already satisfied: pretrainedmodels>=0.7.1 in /opt/app-root/lib64/python3.11/site-packages (from segmentation-models-pytorch->terratorch==0.99.9) (0.7.4)
# Requirement already satisfied: safetensors in /opt/app-root/lib64/python3.11/site-packages (from timm>=1.0.15->terratorch==0.99.9) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/app-root/lib64/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/app-root/lib64/python3.11/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib64/python3.11/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib64/python3.11/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/app-root/lib64/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: Mako in /opt/app-root/lib64/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==2.20.3->terratorch==0.99.9) (1.3.9)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/app-root/lib64/python3.11/site-packages (from Flask<4->mlflow==2.20.3->terratorch==0.99.9) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /opt/app-root/lib64/python3.11/site-packages (from Flask<4->mlflow==2.20.3->terratorch==0.99.9) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/app-root/lib64/python3.11/site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (3.11.12)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/app-root/lib64/python3.11/site-packages (from graphene<4->mlflow==2.20.3->terratorch==0.99.9) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/app-root/lib64/python3.11/site-packages (from graphene<4->mlflow==2.20.3->terratorch==0.99.9) (3.2.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /opt/app-root/lib64/python3.11/site-packages (from hydra-core>=1.0.0->lightly==1.5.19->terratorch==0.99.9) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/app-root/lib64/python3.11/site-packages (from hydra-core>=1.0.0->lightly==1.5.19->terratorch==0.99.9) (4.9.3)
# Requirement already satisfied: kornia_rs>=0.1.0 in /opt/app-root/lib64/python3.11/site-packages (from kornia>=0.7.3->torchgeo==0.6.2->terratorch==0.99.9) (0.1.8)
# Requirement already satisfied: rich<14.0,>=12.3.0 in /opt/app-root/lib64/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (13.9.4)
# Requirement already satisfied: tensorboardX<3.0,>=2.2 in /opt/app-root/lib64/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (2.6.2.2)
# Requirement already satisfied: bitsandbytes<1.0,>=0.44.0 in /opt/app-root/lib64/python3.11/site-packages (from lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (0.45.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib64/python3.11/site-packages (from matplotlib<4->mlflow==2.20.3->terratorch==0.99.9) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib64/python3.11/site-packages (from matplotlib<4->mlflow==2.20.3->terratorch==0.99.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib64/python3.11/site-packages (from matplotlib<4->mlflow==2.20.3->terratorch==0.99.9) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/app-root/lib64/python3.11/site-packages (from matplotlib<4->mlflow==2.20.3->terratorch==0.99.9) (1.4.8)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib64/python3.11/site-packages (from pandas>=1.4.0->geopandas==1.0.1->terratorch==0.99.9) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/app-root/lib64/python3.11/site-packages (from pandas>=1.4.0->geopandas==1.0.1->terratorch==0.99.9) (2025.1)
# Requirement already satisfied: munch in /opt/app-root/lib64/python3.11/site-packages (from pretrainedmodels>=0.7.1->segmentation-models-pytorch->terratorch==0.99.9) (4.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/app-root/lib64/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.6->terratorch==0.99.9) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/app-root/lib64/python3.11/site-packages (from pydantic>=2.7.0->albumentations==1.4.6->terratorch==0.99.9) (2.27.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.6->terratorch==0.99.9) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.6->terratorch==0.99.9) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image>=0.21.0->albumentations==1.4.6->terratorch==0.99.9) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/app-root/lib64/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.6->terratorch==0.99.9) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/app-root/lib64/python3.11/site-packages (from scikit-learn>=1.3.2->albumentations==1.4.6->terratorch==0.99.9) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/app-root/lib64/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.20.3->terratorch==0.99.9) (3.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/app-root/lib64/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.0.post0->terratorch==0.99.9) (1.18.3)
# Requirement already satisfied: google-auth~=2.0 in /opt/app-root/lib64/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (2.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/app-root/lib64/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /opt/app-root/lib64/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in /opt/app-root/lib64/python3.11/site-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in /opt/app-root/lib64/python3.11/site-packages (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (2.7.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/app-root/lib64/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b0 in /opt/app-root/lib64/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (0.52b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/app-root/lib64/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/app-root/lib64/python3.11/site-packages (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (2.19.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/app-root/lib64/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/app-root/lib64/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib64/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib64/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (4.9)
# Requirement already satisfied: mdurl~=0.1 in /opt/app-root/lib64/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/app-root/lib64/python3.11/site-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,>=2->torchgeo==0.6.2->terratorch==0.99.9) (6.5.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/app-root/lib64/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.3->mlflow==2.20.3->terratorch==0.99.9) (0.6.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import sys
import torch
import gdown
import terratorch
import albumentations
import lightning.pytorch as pl
import matplotlib.pyplot as plt
from pathlib import Path
from terratorch.datamodules import GenericNonGeoSegmentationDataModule
import warnings
os.environ["TENSORBOARD_PROXY_URL"]= os.environ["NB_PREFIX"]+"/proxy/6006/"
warnings.filterwarnings('ignore')

# %% [markdown]
# 3. Download the dataset from Google Drive

# %%
if not os.path.isfile('hls_burn_scars.tar.gz'):
    gdown.download("https://drive.google.com/uc?id=1yFDNlGqGPxkc9lh9l1O70TuejXAQYYtC")

if not os.path.isdir('hls_burn_scars/'):
    # !tar -xzvf hls_burn_scars.tar.gz

# %% [markdown]
# ## HLS Burn Scars Dataset
#
# Lets start with analyzing the dataset

# %%
dataset_path = Path('hls_burn_scars')
# !ls "hls_burn_scars/"
# Out:
# data  splits

# %%
# !ls "hls_burn_scars/data/" | head
# Out:
# subsetted_512x512_HLS.S30.T10SDH.2020248.v1.4.mask.tif
# subsetted_512x512_HLS.S30.T10SDH.2020248.v1.4_merged.tif
# subsetted_512x512_HLS.S30.T10SEH.2018190.v1.4.mask.tif
# subsetted_512x512_HLS.S30.T10SEH.2018190.v1.4_merged.tif
# subsetted_512x512_HLS.S30.T10SEH.2018245.v1.4.mask.tif
# subsetted_512x512_HLS.S30.T10SEH.2018245.v1.4_merged.tif
# subsetted_512x512_HLS.S30.T10SEH.2018280.v1.4.mask.tif
# subsetted_512x512_HLS.S30.T10SEH.2018280.v1.4_merged.tif
# subsetted_512x512_HLS.S30.T10SEH.2019305.v1.4.mask.tif
# subsetted_512x512_HLS.S30.T10SEH.2019305.v1.4_merged.tif
# ls: write error: Broken pipe

# %%
datamodule = terratorch.datamodules.GenericNonGeoSegmentationDataModule(
    batch_size=4,
    num_workers=2,
    num_classes=2,

    # Define dataset paths 
    train_data_root=dataset_path / 'data/',
    train_label_data_root=dataset_path / 'data/',
    val_data_root=dataset_path / 'data/',
    val_label_data_root=dataset_path / 'data/',
    test_data_root=dataset_path / 'data/',
    test_label_data_root=dataset_path / 'data/',

    # Define splits
    train_split=dataset_path / 'splits/train.txt',
    val_split=dataset_path / 'splits/val.txt',
    test_split=dataset_path / 'splits/test.txt',
    
    img_grep='*_merged.tif',
    label_grep='*.mask.tif',
    
    train_transform=[
        albumentations.D4(), # Random flips and rotation
        albumentations.pytorch.transforms.ToTensorV2(),
    ],
    val_transform=None,  # Using ToTensor() by default
    test_transform=None,
        
    # Define standardization values
    means=[
      0.0333497067415863,
      0.0570118552053618,
      0.0588974813200132,
      0.2323245113436119,
      0.1972854853760658,
      0.1194491422518656,
    ],
    stds=[
      0.0226913556882377,
      0.0268075602230702,
      0.0400410984436278,
      0.0779173242367269,
      0.0870873883814014,
      0.0724197947743781,
    ],
    no_data_replace=0,
    no_label_replace=-1,
    # We use all six bands of the data, so we don't need to define dataset_bands and output_bands.
)

# Setup train and val datasets
datamodule.setup("fit")

# %%
# checking datasets train split size
train_dataset = datamodule.train_dataset
len(train_dataset)
# Out:
# 524

# %%
# checking datasets validation split size
val_dataset = datamodule.val_dataset
len(val_dataset)
# Out:
# 160

# %%
# plotting a few samples
val_dataset.plot(val_dataset[0])
val_dataset.plot(val_dataset[6])
val_dataset.plot(val_dataset[10])

# %%
# checking datasets testing split size
datamodule.setup("test")
test_dataset = datamodule.test_dataset
len(test_dataset)
# Out:
# 120

# %% [markdown]
# # Fine-tune Prithvi

# %%
pl.seed_everything(0)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    dirpath="output/burnscars/checkpoints/",
    mode="max",
    monitor="val/Multiclass_Jaccard_Index", # Variable to monitor
    filename="best-{epoch:02d}",
)

# Lightning Trainer
trainer = pl.Trainer(
    accelerator="auto",
    strategy="auto",
    devices=1, # Deactivate multi-gpu because it often fails in notebooks
    precision='bf16-mixed',  # Speed up training
    num_nodes=1,
    logger=True,  # Uses TensorBoard by default
    max_epochs=100, # For demos
    log_every_n_steps=1,
    enable_checkpointing=True,
    callbacks=[checkpoint_callback, pl.callbacks.RichProgressBar()],
    default_root_dir="output/burnscars",
    detect_anomaly=True,
)

# Model
model = terratorch.tasks.SemanticSegmentationTask(
    model_factory="EncoderDecoderFactory",
    model_args={
        # Backbone
        "backbone": "prithvi_eo_v2_300", # Model can be either prithvi_eo_v1_100, prithvi_eo_v2_300, prithvi_eo_v2_300_tl, prithvi_eo_v2_600, prithvi_eo_v2_600_tl
        "backbone_pretrained": True,
        "backbone_num_frames": 1, # 1 is the default value,
        "backbone_img_size": 512,
        "backbone_bands": ["BLUE", "GREEN", "RED", "NIR_NARROW", "SWIR_1", "SWIR_2"],
        # "backbone_coords_encoding": [], # use ["time", "location"] for time and location metadata
        
        # Necks 
        "necks": [
            {
                "name": "SelectIndices",
                # "indices": [2, 5, 8, 11] # indices for prithvi_eo_v1_100
                "indices": [5, 11, 17, 23] # indices for prithvi_eo_v2_300
                # "indices": [7, 15, 23, 31] # indices for prithvi_eo_v2_600
            },
            {"name": "ReshapeTokensToImage",},
            {"name": "LearnedInterpolateToPyramidal"}            
        ],
        
        # Decoder
        "decoder": "UNetDecoder",
        "decoder_channels": [512, 256, 128, 64],
        
        # Head
        "head_dropout": 0.1,
        "num_classes": 2,
    },
    
    loss="ce",
    optimizer="AdamW",
    lr=1e-4,
    ignore_index=-1,
    freeze_backbone=True, # Only to speed up fine-tuning
    freeze_decoder=False,
    plot_on_val=True,
    class_names=['no burned', 'burned']  # optionally define class names
)
# Out:
# Seed set to 0
# Using bfloat16 Automatic Mixed Precision (AMP)
# You have turned on `Trainer(detect_anomaly=True)`. This will significantly slow down compute speed and is recommended only for model debugging.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO:root:Loaded weights for HLSBands.BLUE in position 0 of patch embed
# INFO:root:Loaded weights for HLSBands.GREEN in position 1 of patch embed
# INFO:root:Loaded weights for HLSBands.RED in position 2 of patch embed
# INFO:root:Loaded weights for HLSBands.NIR_NARROW in position 3 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_1 in position 4 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_2 in position 5 of patch embed

# %%
# %load_ext tensorboard
# %tensorboard --logdir output
# Out:
#       <iframe id="tensorboard-frame-629f6fbed82c07cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-629f6fbed82c07cd");
#           const url = new URL("/notebook/paolofraccaro-workshop/paolofraccaro-workshop/proxy/6006/", window.location);
#           const port = 0;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Training
trainer.fit(model, datamodule=datamodule)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ PixelWiseModel   │  324 M │ train │
# │ 1 │ criterion     │ CrossEntropyLoss │      0 │ train │
# │ 2 │ train_metrics │ MetricCollection │      0 │ train │
# │ 3 │ val_metrics   │ MetricCollection │      0 │ train │
# │ 4 │ test_metrics  │ ModuleList       │      0 │ train │
# └───┴───────────────┴──────────────────┴────────┴───────┘
# Trainable params: 20.3 M
# Non-trainable params: 303 M
# Total params: 324 M
# Total estimated model params size (MB): 1.3 K
# Modules in train mode: 617
# Modules in eval mode: 0
# Output()
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
best_ckpt_path = "output/burnscars/checkpoints/best-epoch=69.ckpt"

# %%
trainer.test(model, datamodule=datamodule, ckpt_path=best_ckpt_path)
# Out:
# Restoring states from the checkpoint path at output/burnscars/checkpoints/best-epoch=69.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at output/burnscars/checkpoints/best-epoch=69.ckpt
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃              Test metric              ┃             DataLoader 0              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test/Multiclass_Accuracy        │          0.9807682633399963           │
# │       test/Multiclass_F1_Score        │          0.9807683825492859           │
# │     test/Multiclass_Jaccard_Index     │          0.9024698734283447           │
# │  test/Multiclass_Jaccard_Index_Micro  │          0.9622624516487122           │
# │               test/loss               │          0.06332477927207947          │
# │    test/multiclassaccuracy_burned     │          0.8761271834373474           │
# │   test/multiclassaccuracy_no burned   │          0.9929506182670593           │
# │  test/multiclassjaccardindex_burned   │          0.8261050581932068           │
# │ test/multiclassjaccardindex_no burned │          0.9788346886634827           │
# └───────────────────────────────────────┴───────────────────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [{'test/loss': 0.06332477927207947,
#   'test/Multiclass_Accuracy': 0.9807682633399963,
#   'test/multiclassaccuracy_no burned': 0.9929506182670593,
#   'test/multiclassaccuracy_burned': 0.8761271834373474,
#   'test/Multiclass_F1_Score': 0.9807683825492859,
#   'test/Multiclass_Jaccard_Index': 0.9024698734283447,
#   'test/multiclassjaccardindex_no burned': 0.9788346886634827,
#   'test/multiclassjaccardindex_burned': 0.8261050581932068,
#   'test/Multiclass_Jaccard_Index_Micro': 0.9622624516487122}]

# %%
# now we can use the model for predictions and plotting!
model = terratorch.tasks.SemanticSegmentationTask.load_from_checkpoint(
    best_ckpt_path,
    model_factory=model.hparams.model_factory,
    model_args=model.hparams.model_args,
)

test_loader = datamodule.test_dataloader()

with torch.no_grad():
    batch = next(iter(test_loader))
    images = datamodule.aug(batch)
    images = batch["image"].to(model.device)
    masks = batch["mask"].numpy()

    outputs = model(images)
    preds = torch.argmax(outputs.output, dim=1).cpu().numpy()

for i in range(4):
    sample = {key: batch[key][i] for key in batch}
    sample["prediction"] = preds[i]
    sample["image"] = sample["image"].cpu()
    sample["mask"] = sample["mask"].cpu()
    test_dataset.plot(sample)
# Out:
# INFO:root:Loaded weights for HLSBands.BLUE in position 0 of patch embed
# INFO:root:Loaded weights for HLSBands.GREEN in position 1 of patch embed
# INFO:root:Loaded weights for HLSBands.RED in position 2 of patch embed
# INFO:root:Loaded weights for HLSBands.NIR_NARROW in position 3 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_1 in position 4 of patch embed
# INFO:root:Loaded weights for HLSBands.SWIR_2 in position 5 of patch embed

# %% [markdown]
# # Fine-tuning via CLI
#
# You might want to restart the session to free up GPU memory.

# %%
# Run fine-tuning
# !terratorch fit -c prithvi_v2_eo_300_tl_unet_burnscars.yaml
